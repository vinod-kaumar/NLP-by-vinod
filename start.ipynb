# %% [markdown]
# <h1>NLP Pipeline</h1>

# %% [markdown]
# 1. DataAcquisition
# 2. Text preprocessing
#     - text cleanup
#     - basic preprocssing --> vectorization
#     - advance preprocessing --> POS taggin, NER etc
# 3. Feature engineering
#     - embedding etc
#     - we need correct data for model training
# 4. Modeling
#     - Model building
#     - evaluation
# 5. Deployment
#     - Deploy
#     - monitoring
#     - model updating
