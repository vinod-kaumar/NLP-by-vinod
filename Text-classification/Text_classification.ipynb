# %% [markdown]
# # Text - classification using ML

# %% [markdown]
# ## Data Acquisition

# %%
# !pip install kagglehub

# %%
import kagglehub

# Download dataset
path = kagglehub.dataset_download(
    "lakshmi25npathi/imdb-dataset-of-50k-movie-reviews"
)

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'imdb-dataset-of-50k-movie-reviews' dataset.
# Path to dataset files: /kaggle/input/imdb-dataset-of-50k-movie-reviews

# %%
import os

print(os.listdir(path))
# Out:
# ['IMDB Dataset.csv']

# %%
import pandas as pd
import os

csv_path = os.path.join(path, "IMDB Dataset.csv")

df = pd.read_csv(csv_path)

df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ## EDA

# %%
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(418)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### 1. Lowercasing

# %%
df['review'] = df['review'].str.lower()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ### 2. Removing HTML tags

# %%
df.review[0]
# Out:
# "one of the other reviewers has mentioned that after watching just 1 oz episode you'll be hooked. they are right, as this is exactly what happened with me.<br /><br />the first thing that struck me about oz was its brutality and unflinching scenes of violence, which set in right from the word go. trust me, this is not a show for the faint hearted or timid. this show pulls no punches with regards to drugs, sex or violence. its is hardcore, in the classic use of the word.<br /><br />it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />i would say the main appeal of the show is due to the 
# ...

# %%
import re
def remove_tags(text):
  pattern = r'<.*?>'
  return re.sub(pattern, "", text);

# %%
df['review'] = df['review'].apply(remove_tags)

# %%
df["review"][0]
# Out:
# "one of the other reviewers has mentioned that after watching just 1 oz episode you'll be hooked. they are right, as this is exactly what happened with me.the first thing that struck me about oz was its brutality and unflinching scenes of violence, which set in right from the word go. trust me, this is not a show for the faint hearted or timid. this show pulls no punches with regards to drugs, sex or violence. its is hardcore, in the classic use of the word.it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.i would say the main appeal of the show is due to the fact that it goes where other shows 
# ...

# %% [markdown]
# ### 3. Removing URLs

# %%
import re

def remove_urls(text):
    pattern = r'https?://\S+|www\.\S+'
    text = re.sub(pattern, '', text)
    print(re.findall(pattern, text))
    return re.sub(r'\s+', ' ', text).strip()

# %%
df['review'] = df['review'].apply(remove_urls)
# Out:
# Streaming output truncated to the last 5000 lines.
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %% [markdown]
# ### 4. Remove Punctuations

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %%
import string
exclude = string.punctuation

# %%
def remove_punctuations(text):
  return text.translate(str.maketrans('', '', exclude))

# %%
import time
start = time.time()
df['review'] = df['review'].apply(remove_punctuations)
end = time.time()
print(end - start)
# Out:
# 1.8241798877716064

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production the filming tech...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %% [markdown]
# ### 5. Chat conversation

# %% [markdown]
# ### 6. Spelling correction

# %%
from textblob import TextBlob

# %%
def correct_spelling(text):
  return TextBlob(text).correct().string

# %%
correct_spelling("ceertain conditionas duriiing several ggennerations aree modifiedss in the saame manerr.")
# Out:
# 'certain conditions during several generations are modified in the same manner.'

# %%
# df['review'] = df['review'].apply(correct_spelling)

# %% [markdown]
# ### 7. Removing Stop Words

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    filtered_words = [
        word for word in text.split()
        if word.lower() not in stop_words
    ]
    return ' '.join(filtered_words)

# %%
df['review'] = df['review'].apply(remove_stopwords)

# %% [markdown]
# ### 8. Demojize

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 11.0 MB/s eta 0:00:00
# ...

# %%
import emoji

# %%
def text_demojize(text):
  return emoji.demojize(text)

# %%
df['review'] = df['review'].apply(text_demojize)

# %% [markdown]
# ### 9. Stemming

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem_words(text):
  return " ".join(ps.stem(word) for word in text.split())

# %%
df['review'] = df['review'].apply(stem_words)

# %% [markdown]
# **I will do this part next day so i stored this cleaned df**

# %%
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings("ignore")

# %%
save_path = "/content/drive/MyDrive/NLP/Text-classification/cleaned_imdb.csv"

# df.to_csv(save_path, index=False)

# print("File saved successfully")

# %%
df = pd.read_csv(save_path)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one review mention watch 1 oz episod youll hoo...  positive
# 1  wonder littl product film techniqu unassum old...  positive
# 2  thought wonder way spend time hot summer weeke...  positive
# 3  basic there famili littl boy jake think there ...  negative
# 4  petter mattei love time money visual stun film...  positive

# %% [markdown]
# # Modelling - ML approach

# %% [markdown]
# ## 1. with BOW

# %%
X = df.drop('sentiment', axis = 1)
y = df['sentiment']

# %%
X.shape, y.shape
# Out:
# ((49582, 1), (49582,))

# %%
X.head()
# Out:
#                                               review
# 0  one review mention watch 1 oz episod youll hoo...
# 1  wonder littl product film techniqu unassum old...
# 2  thought wonder way spend time hot summer weeke...
# 3  basic there famili littl boy jake think there ...
# 4  petter mattei love time money visual stun film...

# %%
y.head()
# Out:
# 0    positive
# 1    positive
# 2    positive
# 3    negative
# 4    positive
# Name: sentiment, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y = encoder.fit_transform(y)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((39665, 1), (9917, 1), (39665,), (9917,))

# %%
# applying BOW
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000) # if we take frequent 5k words accuracy is good if we increase it decreases

# %%
X_train_bow = cv.fit_transform(X_train['review']).toarray()

# %%
X_train_bow.shape
# Out:
# (39665, 5000)

# %%
X_test_bow = cv.transform(X_test['review']).toarray()

# %%
X_test_bow.shape
# Out:
# (9917, 5000)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X_train_bow, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7245134617323787

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[4229,  705],
#        [2027, 2956]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

rf.fit(X_train_bow, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test_bow)
accuracy_score(y_test, y_pred)
# Out:
# 0.8430977110013109

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[4124,  810],
#        [ 746, 4237]])

# %% [markdown]
# ## 2. using ngrams

# %%
# applying ngrams
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range = (2,2), max_features = 5000)

X_train_bow = cv.fit_transform(X_train['review']).toarray()
X_test_bow = cv.transform(X_test['review']).toarray()

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

gnb.fit(X_train_bow, y_train)

y_pred = gnb.predict(X_test_bow)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.7897549662196228
# [[3643 1291]
#  [ 794 4189]]

# %%
# applying ngrams
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range = (1,2), max_features = 5000)

X_train_bow = cv.fit_transform(X_train['review']).toarray()
X_test_bow = cv.transform(X_test['review']).toarray()

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

gnb.fit(X_train_bow, y_train)

y_pred = gnb.predict(X_test_bow)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.8060905515780982
# [[4249  685]
#  [1238 3745]]

# %% [markdown]
# ## 3. Using TfIdf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features = 5000)

X_train_tfidf = tfidf.fit_transform(X_train['review']).toarray()
X_test_tfidf = tfidf.transform(X_test['review']).toarray()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

gnb.fit(X_train_bow, y_train)

y_pred = gnb.predict(X_test_bow)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.8060905515780982
# [[4249  685]
#  [1238 3745]]

# %% [markdown]
# ## 4. Word2Vec

# %% [markdown]
# - pretrained model (80% vocab should be matched)
# - self-trained word2vec
# - If we have enough data then go for self-trained word2vec

# %% [markdown]
# - Sentence word2vec or Document word2vec
# - we take average of all the word2vec of words of sentence

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one review mention watch 1 oz episod youll hoo...  positive
# 1  wonder littl product film techniqu unassum old...  positive
# 2  thought wonder way spend time hot summer weeke...  positive
# 3  basic there famili littl boy jake think there ...  negative
# 4  petter mattei love time money visual stun film...  positive

# %%
df['review'][0]
# Out:
# 'one review mention watch 1 oz episod youll hook right exactli happen meth first thing struck oz brutal unflinch scene violenc set right word go trust show faint heart timid show pull punch regard drug sex violenc hardcor classic use wordit call oz nicknam given oswald maximum secur state penitentari focus mainli emerald citi experiment section prison cell glass front face inward privaci high agenda em citi home manyaryan muslim gangsta latino christian italian irish moreso scuffl death stare dodgi deal shadi agreement never far awayi would say main appeal show due fact goe show wouldnt dare forget pretti pictur paint mainstream audienc forget charm forget romanceoz doesnt mess around first episod ever saw struck nasti surreal couldnt say readi watch develop tast oz got accustom high level graphic violenc violenc injustic crook guard wholl sold nickel inmat wholl kill order get away well manner middl class inmat turn prison bitch due lack street skill prison experi watch oz may becom
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 53.0 MB/s eta 0:00:00
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
story = []
for doc in df['review']:
  raw_sentence =  sent_tokenize(doc)
  for sent in raw_sentence:
    story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 49582

# %%
story[:2]
# Out:
# [['one',
#   'review',
#   'mention',
#   'watch',
#   'oz',
#   'episod',
#   'youll',
#   'hook',
#   'right',
#   'exactli',
#   'happen',
#   'meth',
#   'first',
#   'thing',
#   'struck',
#   'oz',
#   'brutal',
#   'unflinch',
#   'scene',
#   'violenc',
#   'set',
#   'right',
#   'word',
#   'go',
#   'trust',
#   'show',
#   'faint',
#   'heart',
#   'timid',
#   'show',
#   'pull',
#   'punch',
#   'regard',
#   'drug',
#   'sex',
#   'violenc',
#   'hardcor',
#   'classic',
#   'use',
#   'wordit',
#   'call',
#   'oz',
#   'nicknam',
#   'given',
#   'oswald',
#   'maximum',
#   'secur',
#   'state',
#   'penitentari',
#   'focus',
#   'mainli',
#   'emerald',
#   'citi',
#   'experiment',
#   'section',
#   'prison',
#   'cell',
#   'glass',
#   'front',
#   'face',
#   'inward',
#   'privaci',
#   'high',
#   'agenda',
#   'em',
#   'citi',
#   'home',
#   'manyaryan',
#   'muslim',
#   'gangsta',
#   'latino',
#   'christian',
#   'italian',
#   'irish',
# ...

# %%
import gensim
model = gensim.models.Word2Vec(
    window = 10,
    min_count = 2
)

# %%
model.build_vocab(story)

# %%
model.wv['one']
# Out:
# array([ 9.4563962e-05,  3.0773198e-03, -6.8126451e-03, -1.3754654e-03,
#         7.6685809e-03,  7.3464094e-03, -3.6732971e-03,  2.6427018e-03,
#        -8.3171297e-03,  6.2054861e-03, -4.6373224e-03, -3.1641065e-03,
#         9.3113566e-03,  8.7338570e-04,  7.4907029e-03, -6.0740625e-03,
#         5.1605068e-03,  9.9228229e-03, -8.4573915e-03, -5.1356913e-03,
#        -7.0648370e-03, -4.8626517e-03, -3.7785638e-03, -8.5361991e-03,
#         7.9556061e-03, -4.8439382e-03,  8.4236134e-03,  5.2625705e-03,
#        -6.5500261e-03,  3.9578713e-03,  5.4701497e-03, -7.4265362e-03,
#        -7.4057197e-03, -2.4752307e-03, -8.6257253e-03, -1.5815723e-03,
#        -4.0343284e-04,  3.2996845e-03,  1.4418805e-03, -8.8142155e-04,
#        -5.5940580e-03,  1.7303658e-03, -8.9737179e-04,  6.7936908e-03,
#         3.9735902e-03,  4.5294715e-03,  1.4343059e-03, -2.6998555e-03,
#        -4.3668128e-03, -1.0320747e-03,  1.4370275e-03, -2.6460087e-03,
# ...

# %%
len(model.wv['one'])
# Out:
# 100

# %%
model.train(story, total_examples = model.corpus_count, epochs = 10)
# Out:
# (54538528, 58739660)

# %%
model.corpus_count
# Out:
# 49582

# %%
model.wv['one']
# Out:
# array([ 1.7448882 , -1.8002834 ,  1.3540196 , -0.5521664 , -1.281821  ,
#        -0.6878403 , -1.3305739 , -1.5397794 , -0.881232  ,  0.30934447,
#         0.6644732 ,  0.5344124 ,  1.0291394 ,  0.99647146, -0.2251468 ,
#         0.6647736 ,  1.7684122 ,  0.9429455 , -0.7695917 ,  0.02983123,
#        -3.562232  , -0.98126584, -0.07478832,  1.174019  , -0.49373606,
#         0.22986656,  1.5318393 , -1.1023105 ,  1.6323711 ,  1.2030334 ,
#         1.2810599 , -1.0801123 , -1.9904115 ,  0.6758903 , -1.2315434 ,
#        -1.2597947 , -0.89445275,  1.0972548 ,  0.9306936 ,  1.3934528 ,
#         0.05562997, -0.45432225,  0.06037134,  0.556308  ,  0.2407024 ,
#         3.044941  ,  2.1088405 ,  0.6226476 , -0.02261316, -0.11449751,
#        -0.3285533 ,  1.2835246 ,  0.61008936,  0.39390045,  0.04274148,
#         0.39781728, -0.2575262 ,  1.1894776 , -0.2608852 ,  0.70474684,
#        -0.73960376,  0.79547215,  0.6048213 , -0.39808005, -0.7778443 ,
# ...

# %%
model.wv.index_to_key

# %%
len(model.wv.index_to_key)
# Out:
# 57740

# %%
# index_to_key --> highest frequent words to lowest frequent word

# %%
def document_vector(doc):
  doc = [word for word in doc.split() if word in model.wv.index_to_key]
  return np.mean(model.wv[doc], axis = 0)

# %%
document_vector(df['review'][0])
# Out:
# array([ 6.22317970e-01,  4.26332414e-01,  9.20177758e-01,  3.79578397e-02,
#        -2.62321830e-01, -2.25500450e-01, -5.51604211e-01, -3.79831582e-01,
#        -5.60001016e-01,  2.45707840e-01, -3.63391966e-01, -3.41524512e-01,
#        -2.04889670e-01, -4.52562347e-02,  4.13032383e-01,  2.90939063e-01,
#        -2.26752236e-01,  5.40310800e-01, -1.97294191e-01,  5.74474871e-01,
#        -6.64948165e-01,  5.21595478e-02, -3.83549511e-01,  2.73245066e-01,
#         1.23325698e-01,  5.68523169e-01, -1.77523211e-01, -5.73429167e-01,
#         6.77121162e-01,  5.35376966e-01,  1.63690642e-01, -7.66198814e-01,
#        -1.41981587e-01,  2.36807585e-01, -2.47008815e-01,  3.70818585e-01,
#         3.64369363e-01,  1.74923912e-01, -4.20152992e-01,  3.37056990e-04,
#         4.72579300e-01, -3.65450203e-01, -1.21491142e-01,  5.47766805e-01,
#        -6.31581023e-02,  2.67330825e-01, -1.15964413e-01, -6.57943726e-01,
# ...

# %%
X = df['review'].apply(document_vector)

# %%
X
# Out:
# 0        [0.62231797, 0.4263324, 0.92017776, 0.03795784...
# 1        [0.7734357, -0.14394492, 0.26223496, -0.202551...
# 2        [0.8171743, 0.0910292, 0.33592886, -0.17749888...
# 3        [0.7466374, 0.36922103, 0.68950135, -0.3176033...
# 4        [0.82512313, 0.116542645, 0.6111808, 0.1980803...
#                                ...
# 49577    [1.1739092, -0.4743003, 0.4552412, -0.14150813...
# 49578    [0.6636887, -0.4236277, 0.23848031, -0.4702454...
# 49579    [0.68226904, 0.5030894, 1.1270425, 0.7842912, ...
# 49580    [0.32550645, 0.5278281, 0.63936824, -0.2186956...
# 49581    [0.8404159, -0.69429475, -0.011852782, 0.27197...
# Name: review, Length: 49582, dtype: object

# %%
X = np.array(X.tolist())

# %%
X.shape
# Out:
# (49582, 100)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((34707, 100), (14875, 100), (34707,), (14875,))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
gnb = GaussianNB()

gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.7839327731092437
# [[5730 1660]
#  [1554 5931]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
gnb = RandomForestClassifier()

gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.8446386554621849
# [[6123 1267]
#  [1044 6441]]

# %% [markdown]
# - We can use pretrained Word2Vec here

# %% [markdown]
# # Good Practice

# %% [markdown]
# - we should use ensemble techniques
# - Heuristic features should be used in this text-classification , combination
# - first try ML approach then go to DL approach
# - DL approach may improve accuracy by some extent but that is not sufficient , so always try to solve problem using ML approach.
# - handle Imbalanced dataset
