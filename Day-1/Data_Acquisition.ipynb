# %% [markdown]
# # <h1>DATA ACQUISITION</h1>

# %% [markdown]
# <h1>1. Starting with Json data</h1>

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_json("test.json")

# %%
df.head()
# Out:
#       id                                        ingredients
# 0  18009  [baking powder, eggs, all-purpose flour, raisi...
# 1  28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2  41580  [sausage links, fennel bulb, fronds, olive oil...
# 3  29752  [meat cuts, file powder, smoked sausage, okra,...
# 4  35687  [ground black pepper, salt, sausage casings, l...

# %%
df.columns
# Out:
# Index(['id', 'ingredients'], dtype='object')

# %%
df.ingredients[0][0]
# Out:
# 'baking powder'

# %%
#df = pd.read_json(url)

# %% [markdown]
# **Conclusion : json to dataframe , now u can apply EDA or all the step**

# %% [markdown]
# # 2. SQL data

# %%
# !pip install mysql.connector
# run this if not installed
# Out:
# Collecting mysql.connector
#   Using cached mysql-connector-2.2.9.tar.gz (11.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (pyproject.toml): started
#   Building wheel for mysql.connector (pyproject.toml): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp310-cp310-win_amd64.whl size=248050 sha256=735b8c9898be2ca7fae13415f419d689a7a662a79acf4a97bfd34557132b2139
#   Stored in directory: c:\users\blbon\appdata\local\pip\cache\wheels\76\48\9b\da67ff1a18fe8e9d428f9b1a177716d4a7d363d2bbe83bf6cf
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world')

# %%
pd.read_sql_query("SHOW TABLES", conn)
# Out:
#    Tables_in_world
# 0             city
# 1          country
# 2  countrylanguage

# %%
df_city = pd.read_sql_query("SELECT * FROM city", conn)

# %%
df_city.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
df_country = pd.read_sql_query("SELECT * FROM country", conn)

# %%
df_country.head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
# 2                 Angola                                      Republic
# 3               Anguilla                 Dependent Territory of the UK
# 4              Shqipëria                                      Republic
#
#                HeadOfState  Capital Code2
# 0                  Beatrix    129.0    AW
# 1            Mohammad Omar      1.0    AF
# 2  José Eduardo dos Santos     56.0    AO
# 3             Elisabeth II     62.0    AI
# 4           Rexhep Mejdani     34.0    AL

# %% [markdown]
# # 3. Data acquisition using APIs

# %% [markdown]
# API :- application programming interface, used to interface two software or it is a data pipeline

# %%
# use rapid api to get data from api and convert it to dataframe

# %%
# !pip install requests

# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/actors/get-related-news"

querystring = {"limit":"25","nm":"nm0366389"}

headers = {
	"x-rapidapi-key": "2d47fc40b3msh5a8e62db2fa524fp1439dfjsn44bc58ccf4d0",
	"x-rapidapi-host": "imdb232.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'name': {'id': 'nm0366389', 'nameText': {'text': 'Kevin Hart'}, 'news': {'__typename': 'NewsConnection', 'edges': [{'node': {'__typename': 'News', 'id': 'ni65833114', 'byline': None, 'date': '2026-05-09T15:00:10Z', 'externalUrl': 'https://www.tvinsider.com/1262344/best-worst-celebrity-roasts/', 'articleTitle': {'plainText': 'Best & Worst Celebrity Roasts Ever: Bob Saget, Pamela Anderson, Justin Bieber & More'}, 'image': {'__typename': 'Image', 'id': 'rm1120651522', 'url': 'https://m.media-amazon.com/images/M/MV5BZGFmZmIzMDktZDc1NC00NDY1LTk2OWUtMmFlNzA1Yzg0YzZlXkEyXkFqcGc@._V1_.jpg', 'height': 570, 'width': 1014}, 'text': {'plainText': 'Expect long set-ups and short punchlines on Netflix this Sunday (May 10) as the streamer airs The Roast of Kevin Hart live. Kevin Hart has put up with put-downs about his stature before as he helped roast Justin Bieber and Tom Brady, but now he’s in the crosshairs, and we’ll see how many of Sunday’s guests pick on his height. We’ll also have to wait and see how good the special will even be because, as you can see below, not every roast has been fire. Drawing from archival clips and online consensus, we’re presenting our picks for the best and worst celebrity roasts from TV history.'}, 'source': {'homepage': {'url': 'https://www.tvinsider.com/', 'label': 'TV Insider'}, 'description': None}}}, {'node': {'__typename': 'News', 'id': 'ni65831664', 'byline': 'Scott Feinberg', 'date': '2026-05-08T12:00:00Z', 'externalUrl': 'https://www.hollywoodreporter.com/movies/movie-news/cannes-sandra-huller-thr-awards-chatter-pod-guest-1236587142/', 'articleTitle': {'plainText': 'Cannes: Sandra Hüller, Star of Competition Film ‘Fatherland,’ Will Guest on THR’s ‘Awards Chatter’ Pod Live From Palais'}, 'image': {'__typename': 'Image', 'id': 'rm1192413186', 'url': 'https://m.media-amazon.com/images/M/MV5BYTQ5YWE1MjYtOTNmYS00MmI4LWExMDItNGY5ZjIyZjIzMzZmXkEyXkFqcGc@._V1_.jpg', 'height': 200, 'width': 200}, 'text': {'plainText': 'The Hollywood Reporter and Campari are pleased to invite attendees of the upcoming Cannes Film Festival to a very special event: a live recording of THR’s Awards Chatter podcast, hosted by yours truly, with Sandra Hüller, the Oscar-nominated German actress.\n\nThe event, which will take place on Friday, May 15, at 11:30 am local time in the exclusive Campari Lounge within the Palais, will feature an hourlong career-retrospective conversation, followed by a reception.\n\nGiven the venue’s limited space, those wishing to attend are encouraged to RSVP via this link as soon as possible.\n\nHüller shot to international fame as the star of two 2023 films that won top prizes at Cannes en route to best picture Oscar nominations, Anatomy of a Fall and The Zone of Interest, garnering a best actress Oscar nom for the former. Remarkably, she is having an even bigger 2026. In February, she was awarded the Berlin'}, 'source': {'homepage': {'url': 'http://www.hollywoodreporter.com/topic/movies', 'label': 'The Hollywood Reporter - Movie News'}, 'description': None}}}, {'node': {'__typename': 'News', 'id': 'ni65827661', 'byline': 'Christopher Hudspeth', 'date': '2026-05-07T20:40:53Z', 'externalUrl': 'https://www.netflix.com/tudum/features/the-roast-of-kevin-hart-live-on-netflix', 'articleTitle': {'plainText': 'The Roast of Kevin Hart Lineup, Tickets Start Time, How to Watch'}, 'image': {'__typename': 'Image', 'id': 'rm4135438338', 'url': 'https://m.media-amazon.com/images/M/MV5BNmVmN2FjM2EtNzg0Mi00ODM4LWJlNTUtODBjOTcwOGYzOTA4XkEyXkFqcGc@._V1_.jpg', 'height': 584, 'width': 1200}, 'text': {'plainText': 'It’s almost time for the roast master to become the roasted. After years of dominating stages and box offices with his comedy, Kevin Hart — who hosted The Roast of Tom Brady back in 2024 and is fresh off discovering the next great comedian on Funny Af with Kevin Hart — will find his feet being held to the fire, surrendering the mic to a roomful of flamethrowers for The Roast of Kevin Hart.\n\nHosted by  ...

# %%
df = pd.DataFrame(response.json())

# %%
df.head()
# Out:
#                                                    data
# name  {'id': 'nm0366389', 'nameText': {'text': 'Kevi...

# %%
len(df.data)
# Out:
# 1

# %% [markdown]
# # 4. Data Aquisition using Web Scrapng
